# %%
import tabula

# %%
pdf_path = 'sample.pdf'
dfs = tabula.read_pdf(pdf_path, pages='1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# D:\anaconda\conda3\lib\site-packages\tabula\io.py in _run(java_options, options, path, encoding)
#      87     try:
# ---> 88         result = subprocess.run(
#      89             args,
#
# D:\anaconda\conda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     504
# --> 505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
#
# D:\anaconda\conda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
len(dfs)

# %%
print(dfs[0])

# %%
type(dfs)

# %%
dfs.to_csv('pg1_table1.csv')
